# %%
import pandas as pd
import numpy as np

# %%
data = [10,20,"A",40,9.18]
series = pd.Series(data)
print(series)
print(series.dtype)
# Out:
# 0      10
# 1      20
# 2       A
# 3      40
# 4    9.18
# dtype: object
# object

# %%
data = [10,20,30,40,21,12]
i = ["a","b","c","d","e","f"]
series = pd.Series(data, index = i)
print(series)
print(series.dtype)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    21
# f    12
# dtype: int64
# int64

# %%
import pandas as pd
iris_df = pd.read_csv("iris.csv")
print(iris_df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import numpy as np
iris_array = np.array(iris_df)
iris_array
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Setosa'],
# ...

# %%
iris_df.loc[10:15,"sepal.length":"petal.length"]
# Out:
#     sepal.length  sepal.width  petal.length
# 10           5.4          3.7           1.5
# 11           4.8          3.4           1.6
# 12           4.8          3.0           1.4
# 13           4.3          3.0           1.1
# 14           5.8          4.0           1.2
# 15           5.7          4.4           1.5

# %%
data = {"weight": [62,75,84, 96,48,71], \
    "height": [178,165, 186, 165, 174, 167]}
bmi = pd.DataFrame(data)
bmi
# Out:
#    weight  height
# 0      62     178
# 1      75     165
# 2      84     186
# 3      96     165
# 4      48     174
# 5      71     167

# %%
bmi["BMI"]=bmi["weight"]/(bmi["height"]/100) ** 2
bmi
# Out:
#    weight  height        BMI
# 0      62     178  19.568236
# 1      75     165  27.548209
# 2      84     186  24.280264
# 3      96     165  35.261708
# 4      48     174  15.854142
# 5      71     167  25.458066

# %%
bmi. loc[3] = [78,np.nan, np.nan]
bmi
# Out:
#    weight  height        BMI
# 0      62   178.0  19.568236
# 1      75   165.0  27.548209
# 2      84   186.0  24.280264
# 3      78     NaN        NaN
# 4      48   174.0  15.854142
# 5      71   167.0  25.458066

# %%
bmi. loc[5] = [np.nan,69, np.nan]
bmi
# Out:
#    weight  height        BMI
# 0    62.0   178.0  19.568236
# 1    75.0   165.0  27.548209
# 2    84.0   186.0  24.280264
# 3    78.0     NaN        NaN
# 4    48.0   174.0  15.854142
# 5     NaN    69.0        NaN

# %%
bmi.info
# Out:
# <bound method DataFrame.info of    weight  height        BMI
# 0    62.0   178.0  19.568236
# 1    75.0   165.0  27.548209
# 2    84.0   186.0  24.280264
# 3    78.0     NaN        NaN
# 4    48.0   174.0  15.854142
# 5     NaN    69.0        NaN>

# %%
bmi.isnull().sum()
# Out:
# weight    1
# height    1
# BMI       2
# dtype: int64

# %%
bmi["weight"].fillna(62)
bmi
# Out:
#    weight  height        BMI
# 0    62.0   178.0  19.568236
# 1    75.0   165.0  27.548209
# 2    84.0   186.0  24.280264
# 3    78.0     NaN        NaN
# 4    48.0   174.0  15.854142
# 5     NaN    69.0        NaN

# %%
bmi["height"] = bmi["height"].fillna(165)
bmi
# Out:
#    weight  height        BMI
# 0    62.0   178.0  19.568236
# 1    75.0   165.0  27.548209
# 2    84.0   186.0  24.280264
# 3    78.0   165.0        NaN
# 4    48.0   174.0  15.854142
# 5     NaN    69.0        NaN

# %%
bmi["bmi_new"] = bmi["weight"]/(bmi["height"]/100) ** 2
bmi
# Out:
#    weight  height        BMI    bmi_new
# 0    62.0   178.0  19.568236  19.568236
# 1    75.0   165.0  27.548209  27.548209
# 2    84.0   186.0  24.280264  24.280264
# 3    78.0   165.0        NaN  28.650138
# 4    48.0   174.0  15.854142  15.854142
# 5     NaN    69.0        NaN        NaN

# %%
bmi["BMI"] = bmi["BMI"].fillna(17.3333)
bmi
# Out:
#    weight     height        BMI    bmi_new        bmi
# 0    62.0  19.568236  19.568236  19.568236  19.568236
# 1    75.0  27.548209  27.548209  27.548209  27.548209
# 2    84.0  24.280264  24.280264  24.280264  24.280264
# 3    78.0  17.333300  17.333300  28.650138  17.333300
# 4    48.0  15.854142  15.854142  15.854142  15.854142
# 5     NaN  17.333300  17.333300        NaN  17.333300

# %%
bmi["weight"] = bmi["weight"].fillna(96)
bmi
# Out:
#    weight     height        BMI    bmi_new        bmi
# 0    62.0  19.568236  19.568236  19.568236  19.568236
# 1    75.0  27.548209  27.548209  27.548209  27.548209
# 2    84.0  24.280264  24.280264  24.280264  24.280264
# 3    78.0  17.333300  17.333300  28.650138  17.333300
# 4    48.0  15.854142  15.854142  15.854142  15.854142
# 5    96.0  17.333300  17.333300        NaN  17.333300

# %%
bmi["bmi_new"] = bmi["bmi_new"].fillna(15.369)
bmi
# Out:
#    weight     height        BMI    bmi_new        bmi
# 0    62.0  19.568236  19.568236  19.568236  19.568236
# 1    75.0  27.548209  27.548209  27.548209  27.548209
# 2    84.0  24.280264  24.280264  24.280264  24.280264
# 3    78.0  17.333300  17.333300  28.650138  17.333300
# 4    48.0  15.854142  15.854142  15.854142  15.854142
# 5    96.0  17.333300  17.333300  15.369000  17.333300

# %%
bmi.drop("BMI", axis = 1)
# Out:
#    weight     height    bmi_new        bmi
# 0    62.0  19.568236  19.568236  19.568236
# 1    75.0  27.548209  27.548209  27.548209
# 2    84.0  24.280264  24.280264  24.280264
# 3    78.0  17.333300  28.650138  17.333300
# 4    48.0  15.854142  15.854142  15.854142
# 5    96.0  17.333300  15.369000  17.333300

# %%
iris_df = pd.read_csv("iris.csv")

# %%
import matplotlib.pyplot as plt
# plot histogram on selected columns
plt.figure(figsize=(5,3))
plt.title("Histogram")
plt.xlabel("Sepal length")
plt.ylabel("Count")
plt.hist(iris_df["sepal.width"], color="green")
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)
